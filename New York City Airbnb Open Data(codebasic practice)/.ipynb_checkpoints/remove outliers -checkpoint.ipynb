# %% [markdown]
# ## we will see how to remove outliers from our data

# %%
import pandas as pd
df=pd.read_csv("AB_NYC_2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df2=df.price
df2.head(50)
# Out:
# 0     149
# 1     225
# 2     150
# 3      89
# 4      80
# 5     200
# 6      60
# 7      79
# 8      79
# 9     150
# 10    135
# 11     85
# 12     89
# 13     85
# 14    120
# 15    140
# 16    215
# 17    140
# 18     99
# 19    190
# 20    299
# 21    130
# 22     80
# 23    110
# 24    120
# 25     60
# 26     80
# 27    150
# 28     44
# 29    180
# 30     50
# 31     52
# 32     55
# 33     50
# 34     70
# 35     89
# 36     35
# 37     85
# 38    150
# 39     40
# 40     68
# 41    120
# 42    120
# 43    135
# 44    150
# 45    150
# 46    130
# 47    110
# 48    115
# 49     80
# Name: price, dtype: int64

# %%
df2.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df2.median()
# Out:
# 106.0

# %%
df2.mean()
# Out:
# 152.7206871868289

# %%
df2.quantile(1)
# Out:
# 10000.0

# %%
df3=df.price.quantile([0.01,0.999])
df3
# Out:
# 0.010      30.0
# 0.999    3000.0
# Name: price, dtype: float64

# %%
df2.quantile(0.50)
# Out:
# 106.0

# %%
df2.quantile(0.1)
# Out:
# 49.0

# %%
df2.quantile(0.01)
# Out:
# 30.0

# %%
df2.quantile(0.997)
# 99.7%
# Out:
# 1500.0

# %%
min_thresold , max_thresold=df2.quantile([0.01,0.997])
min_thresold , max_thresold
# Out:
# (30.0, 1500.0)

# %%
df_filtered=df[(df.price>min_thresold) & (df.price<max_thresold)]
df_filtered
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df_filtered.shape
# Out:
# (48071, 16)

# %%
df_filtered.price.describe()
# Out:
# count    48071.000000
# mean       144.505253
# std        124.042841
# min         31.000000
# 25%         70.000000
# 50%        109.000000
# 75%        175.000000
# max       1497.000000
# Name: price, dtype: float64

# %% [markdown]
# # We will adjust theresold according to senario

# %% [markdown]
# we will set quantile value if we know that this min or max value cannot be adjustable with dataframe
